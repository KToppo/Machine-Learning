# %% [markdown]
# # Decision Trees
#     Very Intuitive (Easy to understand how it works behind the seen)
#
# # What Is A Tree
# ![image](https://viso.ai/wp-content/smush-webp/2024/04/Visual-Representation-1-1060x596.png.webp)
#
#     If 'Age' == 'middle-aged':
#         return yes
#     else:
#         if (('Age' == young') & ('student?' == no)) | (('Age' == 'senior') & ('Credit_rating?' == 'fair')):
#             return no
#         else:
#             return yes
#
# # Pseudo Code (Steps)
# - Begin with your training dataset, which should have some feature variables and classification or regression output
# - Determine the "best feature" in the dataset to split the data on; more on how we define "best feature" later
# - Split the data into subsets that contain the correct values for this best feature. This splitting basically defines a node on the tree i.e each node is a splitting point based on a certain feature from our data
# - Recursively generate new tree nodes by using the subset of data created from step 3
#
# # Conclusion
# - Programatically speaking, Decision trees are nothing but a giant structure of nested if-else condition
# - Mathematically speaking, Decision trees use hyperplanes which run parallel to any one of the ares of cut your coordinate system into hyper cuboids
#
# # Terminology
# ![image](https://lh7-rt.googleusercontent.com/docsz/AD_4nXd2tu7KRpHf2ZR_F-Sg9THDDChlKOzKwsYZz_EdYXJZYcbJ1jrGPF0YtR9shdod1UmgyhblP-SyihTrHtr2qf2OuLVkXQkClFgk2TLKLfiRoomDIel6uFS5bH05fI8SwBrqP4A48TxX3ryb5pu6zG9FlmGo?key=xOxyNVf2yllNSdFKBNOlBA)
# ![image](https://cdn-images-1.medium.com/max/1760/1*S6IMQT4QkL8IOyhu9JOcPg.png)
#
# # Some Unanswered Questions
# - How to decide which column should be considered as root node?
# - How to select subsequent decision nodes?
# - How to decide splitting criteria in care of numerical columns?
#
# # Advantages
# - Intuitive and easy to understand
# - Minimal data preparation is required
# - The cost of using the tree for inference is logarithmic in the number of data points used to train the tree
#
# # Disadvantages
# - Overfitting
# - Prone to errors for imbalanced datasets
#
# # CART - Classification and Regression Trees
# - The Logic of decision trees can also be applied to regression problems, hence the name CART
#
# # Entropy
#
#     In the most layman terms, Entropy is nothing but the measure of desorder Or you can also call it the measure of purity/impurity.
# **Very Impure > Less Impure > Minimum Impure (Entropy Level)**
#
# ![image](https://images.tpointtech.com/tutorial/machine-learning/images/entropy-in-machine-learning2.png)
#
# # How to Calculate Entropy
#
#     Formula
#         E(s) = sugma(-Pi*log(Pi))
#             Where,
#                 Pi = Probability
#                 log can "natural logarithm" OR "log base 2"
# # Entropy For 2 Class Graph
# ![image](https://miro.medium.com/v2/resize:fit:866/1*T67ZM6FMEf7QoJUwDb8-aw.png)
#
#
# # Observation
# - More the uncertainty more is entropy
# - For a 2 class problem the min entropy is 0 and the max is 1
# - For more then 2 classes the min entropy is 0 and the max can be greater then 1
# - Both "natural logarithm" OR "log base 2" can be used to calculate entropy
#
# # Entropy For Continuous Variables
#
#     How To Pick Heigher Entropy In Continuous Variales
#         Whichever is less peaked KDE (Distribution Graph)
#
# # Information Gain
#
#     Information Gain, is a metric used to train Decision Tree.
#     Specifically, this metric measures the quality of a split.
#         The information gain is based on the decrese in entropy sfter a data-set is split on an attribute. Constructing a decision tree is all about finding attribute that returns the highest information gain
#
# # Formula
#
#     Information Gain = E(parent) - {Weighted Average} * E{Children}
#         Where,
#             E() = Entropy
#
# # Steps
# 1) Calculate the entropy of a parent
# 2) Calculate the entropy for Children
# 3) Calculate the weighted Average of Children
# 4) Calculate the Information Gain
# 5) Calculate the Information Gain for all the columns
#
#         Whichever column has the highest Information Gain (maximum decrease in entropy) the algorithum will select that column to split the data
# 6) Find Information Gain Recursively
#
# **Note**
#
#     When the entropy become ) then class become a leaf node and no more spliting will be perfomed in that dataset
#
#     Decision tree then applies a recursive greedy search algorithm in top bottom fashion to find Information gain st every level of the tree
#
#     Once a leaf node is reached (Entropy = 0), no more splitting is done
#
# # Gini Impurity (Decision Trees)
#
# **In 2 class Dataset**
#
#     Formula
#         GI = 1 - ( (Py)^2 + (Pn)^2 )
#         Where,
#             P = Probability
#             y = Class 1
#             n = Class 2
#
# ![image](https://miro.medium.com/v2/resize:fit:404/0*avdB7itYtq-oKIU7.png)
