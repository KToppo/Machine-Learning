# %% [markdown]
# # Ensemble Learning
# - Meaning of Enseble is group of artist or group of something
# - Ensemble Learing signifies collection of multiple Mashine Lrarning Model
#
# # Ensemble Learning Core Idea
# - Training
# - Prediction
#
# # 2) Prdiction
#
#     | [ Model1-1 ]  +  [ Model-2 ]  +  [ Model-3 ]  +  [ Model-4 ] |      ->      Ensemble Model   where, all models are diffrent
#
#     - What does it mean by all diffrent models
#         1) Same Dataset Diffrent algorithums
#         2) Same algorithum but diffrent Dataset
#         3) Diffrent Dataset with diffrent algorithum
#
#     - How it work with classification (2 Classes)
#
#         If 3 out of 5 models predidct it to be 1 then according to "Majority count logic" the Ensemble model output will be 1
#
#     - How it work with regression
#
#         It take the mean of all the models output
#
# # Types of Ensemble Learning
# 1. Voting Ensemble
# 2. Bagging
#    - Random Forest
# 3. Boosting
#    - Adaboosting
#    - Gradient Boosting
#    - XgBoost
# 4. Stacking
# 5. More ...................
#
# # Disadvantage
#
#     Traning multiple models (Increas the computational complexcity)
#
# # Benefits
# 1) Improvement in performance
# 2) Reduce the bias variance trade off
# 3) Robustness
